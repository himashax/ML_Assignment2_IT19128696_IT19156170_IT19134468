# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
# Import the dataset
data = pd.read_csv('kidney_disease.csv')

# %%
# Display the first five records
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
# Number of rows and columns in the dataset
data.shape
# Out:
# (400, 26)

# %%
# Drop the id column as it is not imporatant for prediction
data.drop('id', axis =1, inplace = True)

# %%
data.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
# Rename the columns
data.columns = ['Age', 'Blood_Pressure', 'Specific_Gravity', 'Albumin', 'Sugar', 'Red_Blood_Cells', 'Pus_Cell','Pus_Cell_Clumps',
                'Bacteria', 'Blood_Glucose_Random', 'Blood_Urea', 'Serum_Creatinine', 'Sodium', 'Potassium', 'Hemoglobin', 
                'Packed_Cell_Volume', 'WhiteBC_Count', 'RedBC_Count', 'Hypertension', 'Diabetes_Mellitus',
                'Coronary_Artery_Disease', 'Appetite', 'Pedal_Edema', 'Anemia', 'Class' ]

data.columns
# Out:
# Index(['Age', 'Blood_Pressure', 'Specific_Gravity', 'Albumin', 'Sugar',
#        'Red_Blood_Cells', 'Pus_Cell', 'Pus_Cell_Clumps', 'Bacteria',
#        'Blood_Glucose_Random', 'Blood_Urea', 'Serum_Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed_Cell_Volume', 'WhiteBC_Count',
#        'RedBC_Count', 'Hypertension', 'Diabetes_Mellitus',
#        'Coronary_Artery_Disease', 'Appetite', 'Pedal_Edema', 'Anemia',
#        'Class'],
#       dtype='object')

# %%
# Describe the dataset
data.describe()
# Out:
#               Age  Blood_Pressure  Specific_Gravity     Albumin       Sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        Blood_Glucose_Random  Blood_Urea  Serum_Creatinine      Sodium  \
# count            356.000000  381.000000        383.000000  313.000000
# mean             148.036517   57.425722          3.072454  137.528754
# std               79.281714   50.503006          5.741126   10.408752
# min               22.000000    1.500000          0.400000    4.500000
# 25%               99.000000   27.000000          0.900000  135.000000
# 50%              121.000000   42.000000          1.300000  138.000000
# 75%              163.000000   66.000000          2.800000  142.000000
# max              490.000000  391.000000         76.000000  163.000000
#
#         Potassium  Hemoglobin
# count  312.000000  348.000000
# mean     4.627244   12.526437
# std      3.193904    2.912587
# min      2.500000    3.100000
# 25%      3.800000   10.300000
# 50%      4.400000   12.650000
# 75%      4.900000   15.000000
# max     47.000000   17.800000

# %%
# Get the no of null values in the columns as a percentage
data.isna().mean()*100
# Out:
# Age                         2.25
# Blood_Pressure              3.00
# Specific_Gravity           11.75
# Albumin                    11.50
# Sugar                      12.25
# Red_Blood_Cells            38.00
# Pus_Cell                   16.25
# Pus_Cell_Clumps             1.00
# Bacteria                    1.00
# Blood_Glucose_Random       11.00
# Blood_Urea                  4.75
# Serum_Creatinine            4.25
# Sodium                     21.75
# Potassium                  22.00
# Hemoglobin                 13.00
# Packed_Cell_Volume         17.50
# WhiteBC_Count              26.25
# RedBC_Count                32.50
# Hypertension                0.50
# Diabetes_Mellitus           0.50
# Coronary_Artery_Disease     0.50
# Appetite                    0.25
# Pedal_Edema                 0.25
# Anemia                      0.25
# Class                       0.00
# dtype: float64

# %%
# Drop columns with more than 30% null values 
data.drop(['Red_Blood_Cells', 'RedBC_Count'], axis = 1, inplace = True)

# Display the remianing columns
data.shape[1]
# Out:
# 23

# %%
# Display the data types of the columns
data.dtypes
# Out:
# Age                        float64
# Blood_Pressure             float64
# Specific_Gravity           float64
# Albumin                    float64
# Sugar                      float64
# Pus_Cell                    object
# Pus_Cell_Clumps             object
# Bacteria                    object
# Blood_Glucose_Random       float64
# Blood_Urea                 float64
# Serum_Creatinine           float64
# Sodium                     float64
# Potassium                  float64
# Hemoglobin                 float64
# Packed_Cell_Volume          object
# WhiteBC_Count               object
# Hypertension                object
# Diabetes_Mellitus           object
# Coronary_Artery_Disease     object
# Appetite                    object
# Pedal_Edema                 object
# Anemia                      object
# Class                       object
# dtype: object

# %%
for feature in data.columns:
    print(feature, ': ', data[feature].unique(), '\n')
# Out:
# Age :  [48.  7. 62. 51. 60. 68. 24. 52. 53. 50. 63. 40. 47. 61. 21. 42. 75. 69.
#  nan 73. 70. 65. 76. 72. 82. 46. 45. 35. 54. 11. 59. 67. 15. 55. 44. 26.
#  64. 56.  5. 74. 38. 58. 71. 34. 17. 12. 43. 41. 57.  8. 39. 66. 81. 14.
#  27. 83. 30.  4.  3.  6. 32. 80. 49. 90. 78. 19.  2. 33. 36. 37. 23. 25.
#  20. 29. 28. 22. 79.]
#
# Blood_Pressure :  [ 80.  50.  70.  90.  nan 100.  60. 110. 140. 180. 120.]
#
# Specific_Gravity :  [1.02  1.01  1.005 1.015   nan 1.025]
#
# Albumin :  [ 1.  4.  2.  3.  0. nan  5.]
#
# Sugar :  [ 0.  3.  4.  1. nan  2.  5.]
#
# Pus_Cell :  ['normal' 'abnormal' nan]
#
# Pus_Cell_Clumps :  ['notpresent' 'present' nan]
#
# Bacteria :  ['notpresent' 'present' nan]
#
# Blood_Glucose_Random :  [121.  nan 423. 117. 106.  74. 100. 410. 138.  70. 490. 380. 208.  98.
#  157.  76.  99. 114. 263. 173.  95. 108. 156. 264. 123.  93. 107. 159.
#  140. 171. 270.  92. 137. 204.  79. 207. 124. 144.  91. 162. 246. 253.
#  141. 182.  86. 150. 146. 425. 112. 250. 360. 163. 129. 133. 102. 158.
#  165. 132. 104. 127. 415. 169. 251. 109. 280. 210. 219. 295.  94. 172.
#  101. 298. 153.  88. 226. 143. 115.  89. 297. 233. 294. 323. 125.  90.
#  308. 118. 224. 128. 122. 214. 213. 268. 256.  84. 105. 288. 139.  78.
#  273. 242. 424. 303. 148. 160. 192. 307. 220. 447. 309.  22. 111. 261.
#  215. 234. 131. 352.  80. 239. 110. 130. 184. 252. 113. 230. 341. 255.
#  103. 238. 248. 120. 241. 269. 201. 203. 463. 176.  82. 119.  97.  96.
#   81. 116. 134.  85.  83.  87.  75.]
#
# Blood_Urea :  [ 36.   18.   53.   56.   26.   25.   54.   31.   60.  107.   55.   72.
#   86.   90.  162.   46.   87.   27.  148.  180.  163.    nan  50.   75.
#   45.   28.  155.   33.   39.  153.   29.   65.  103.   70.   80.   20.
#  202.   77.   89.   24.   17.   32.  114.   66.   38.  164.  142.   96.
#  391.   15.  111.   73.   19.   92.   35.   16.  139.   48.   85.   98.
#  186.   37.   47.   52.   82.   51.  106.   22.  217.   88.  118.   50.1
#   71.   34.   40.   21.  219.   30.  125.  166.   49.  208.  176.   68.
#  145.  165.  322.   23.  235.  132.   76.   42.   44.   41.  113.    1.5
#  146.   58.  133.  137.   67.  115.  223.   98.6 158.   94.   74.  150.
#   61.   57.   95.  191.   93.  241.   64.   79.  215.  309.   10. ]
#
# Serum_Creatinine :  [ 1.2   0.8   1.8   3.8   1.4   1.1  24.    1.9   7.2   4.    2.7   2.1
#   4.6   4.1   9.6   2.2   5.2   1.3   1.6   3.9  76.    7.7    nan  2.4
#   7.3   1.5   2.5   2.    3.4   0.7   1.   10.8   6.3   5.9   0.9   3.
#   3.25  9.7   6.4   3.2  32.    0.6   6.1   3.3   6.7   8.5   2.8  15.
#   2.9   1.7   3.6   5.6   6.5   4.4  10.2  11.5   0.5  12.2   5.3   9.2
#  13.8  16.9   6.    7.1  18.    2.3  13.   48.1  14.2  16.4   2.6   7.5
#   4.3  18.1  11.8   9.3   6.8  13.5  12.8  11.9  12.   13.4  15.2  13.3
#   0.4 ]
#
# Sodium :  [  nan 111.  142.  104.  114.  131.  138.  135.  130.  141.  139.    4.5
#  136.  129.  140.  132.  133.  134.  125.  163.  137.  128.  143.  127.
#  146.  126.  122.  147.  124.  115.  145.  113.  120.  150.  144. ]
#
# Potassium :  [ nan  2.5  3.2  4.   3.7  4.2  5.8  3.4  6.4  4.9  4.1  4.3  5.2  3.8
#   4.6  3.9  4.7  5.9  4.8  4.4  6.6 39.   5.5  5.   3.5  3.6  7.6  2.9
#   4.5  5.7  5.4  5.3 47.   6.3  5.1  5.6  3.   2.8  2.7  6.5  3.3]
#
# Hemoglobin :  [15.4 11.3  9.6 11.2 11.6 12.2 12.4 10.8  9.5  9.4  9.7  9.8  5.6  7.6
#  12.6 12.1 12.7 10.3  7.7 10.9  nan 11.1  9.9 12.5 12.9 10.1 12.  13.
#   7.9  9.3 15.  10.   8.6 13.6 10.2 10.5  6.6 11.   7.5 15.6 15.2  4.8
#   9.1  8.1 11.9 13.5  8.3  7.1 16.1 10.4  9.2  6.2 13.9 14.1  6.  11.8
#  11.7 11.4 14.   8.2 13.2  6.1  8.  12.3  8.4 14.3  9.   8.7 10.6 13.1
#  10.7  5.5  5.8  6.8  8.8  8.5 13.8 11.5  7.3 13.7 12.8 13.4  6.3  3.1
#  17.  15.9 14.5 15.5 16.2 14.4 14.2 16.3 14.8 16.5 15.7 13.3 14.6 16.4
#  16.9 16.  14.7 16.6 14.9 16.7 16.8 15.8 15.1 17.1 17.2 15.3 17.3 17.4
#  17.7 17.8 17.5 17.6]
#
# Packed_Cell_Volume :  ['44' '38' '31' '32' '35' '39' '36' '33' '29' '28' nan '16' '24' '37' '30'
#  '34' '40' '45' '27' '48' '\t?' '52' '14' '22' '18' '42' '17' '46' '23'
#  '19' '25' '41' '26' '15' '21' '43' '20' '\t43' '47' '9' '49' '50' '53'
#  '51' '54']
#
# WhiteBC_Count :  ['7800' '6000' '7500' '6700' '7300' nan '6900' '9600' '12100' '4500'
#  '12200' '11000' '3800' '11400' '5300' '9200' '6200' '8300' '8400' '10300'
#  '9800' '9100' '7900' '6400' '8600' '18900' '21600' '4300' '8500' '11300'
#  '7200' '7700' '14600' '6300' '\t6200' '7100' '11800' '9400' '5500' '5800'
#  '13200' '12500' '5600' '7000' '11900' '10400' '10700' '12700' '6800'
#  '6500' '13600' '10200' '9000' '14900' '8200' '15200' '5000' '16300'
#  '12400' '\t8400' '10500' '4200' '4700' '10900' '8100' '9500' '2200'
#  '12800' '11200' '19100' '\t?' '12300' '16700' '2600' '26400' '8800'
#  '7400' '4900' '8000' '12000' '15700' '4100' '5700' '11500' '5400' '10800'
#  '9900' '5200' '5900' '9300' '9700' '5100' '6600']
#
# Hypertension :  ['yes' 'no' nan]
#
# Diabetes_Mellitus :  ['yes' 'no' ' yes' '\tno' '\tyes' nan]
#
# Coronary_Artery_Disease :  ['no' 'yes' '\tno' nan]
#
# Appetite :  ['good' 'poor' nan]
#
# Pedal_Edema :  ['no' 'yes' nan]
#
# Anemia :  ['no' 'yes' nan]
#
# Class :  ['ckd' 'ckd\t' 'notckd']

# %%
data['Packed_Cell_Volume'] = pd.to_numeric(data['Packed_Cell_Volume'], errors='coerce')
data['WhiteBC_Count'] = pd.to_numeric(data['WhiteBC_Count'], errors='coerce')

print('Data type of Packed_Cell_Volume column: ', data['Packed_Cell_Volume'].dtype)
print('Data type of WhiteBC_Count column: ', data['WhiteBC_Count'].dtype)
# Out:
# Data type of Packed_Cell_Volume column:  float64
# Data type of WhiteBC_Count column:  float64

# %%
data = data.replace({'Diabetes_Mellitus':{'\tno':'no', '\tyes':'yes', ' yes':'yes'} ,
                     'Coronary_Artery_Disease':{'\tno':'no'}, 
                     'Class':{'ckd\t':'ckd'}})

pd.unique(data[['Diabetes_Mellitus', 'Coronary_Artery_Disease', 'Class']].values.ravel())
# Out:
# array(['yes', 'no', 'ckd', 'notckd', nan], dtype=object)

# %%
obj_features = np.array([])
numeric_features = np.array([])

for feature in features:
    if data[feature].dtypes == object:
        obj_features = np.append(obj_features, feature)
    else:
        numeric_features = np.append(numeric_features, feature)

# %%
print('Null values count in Numerical Features \n')

for i in numeric_features:
    print(i, ': ', data[i].isna().sum())
# Out:
# Null values count in Numerical Features
#
# Age :  9
# Blood_Pressure :  12
# Specific_Gravity :  47
# Albumin :  46
# Sugar :  49
# Blood_Glucose_Random :  44
# Blood_Urea :  19
# Serum_Creatinine :  17
# Sodium :  87
# Potassium :  88
# Hemoglobin :  52
# Packed_Cell_Volume :  71
# WhiteBC_Count :  106

# %%
for i in numeric_features:
    data[i].fillna(data[i].mean(), inplace =True)

for i in numeric_features:
    print(i, ': ', data[i].isna().sum())
    
data.head(20)
# Out:
# Age :  0
# Blood_Pressure :  0
# Specific_Gravity :  0
# Albumin :  0
# Sugar :  0
# Blood_Glucose_Random :  0
# Blood_Urea :  0
# Serum_Creatinine :  0
# Sodium :  0
# Potassium :  0
# Hemoglobin :  0
# Packed_Cell_Volume :  0
# WhiteBC_Count :  0
#      Age  Blood_Pressure  Specific_Gravity   Albumin     Sugar  Pus_Cell  \
# 0   48.0       80.000000          1.020000  1.000000  0.000000    normal
# 1    7.0       50.000000          1.020000  4.000000  0.000000    normal
# 2   62.0       80.000000          1.010000  2.000000  3.000000    normal
# 3   48.0       70.000000          1.005000  4.000000  0.000000  abnormal
# 4   51.0       80.000000          1.010000  2.000000  0.000000    normal
# 5   60.0       90.000000          1.015000  3.000000  0.000000       NaN
# 6   68.0       70.000000          1.010000  0.000000  0.000000    normal
# 7   24.0       76.469072          1.015000  2.000000  4.000000  abnormal
# 8   52.0      100.000000          1.015000  3.000000  0.000000  abnormal
# 9   53.0       90.000000          1.020000  2.000000  0.000000  abnormal
# 10  50.0       60.000000          1.010000  2.000000  4.000000  abnormal
# 11  63.0       70.000000          1.010000  3.000000  0.000000  abnormal
# 12  68.0       70.000000          1.015000  3.000000  1.000000    normal
# 13  68.0       70.000000          1.017408  1.016949  0.450142       NaN
# 14  68.0       80.000000          1.010000  3.000000  2.000000  abnormal
# 15  40.0       80.000000          1.015000  3.000000  0.000000    normal
# 16  47.0       70.000000          1.015000  2.000000  0.000000    normal
# 17  47.0       80.000000          1.017408  1.016949  0.450142       NaN
# 18  60.0      100.000000          1.025000  0.000000  3.000000    normal
# 19  62.0       60.000000          1.015000  1.000000  0.000000  abnormal
#
#    Pus_Cell_Clumps    Bacteria  Blood_Glucose_Random  Blood_Urea  ...  \
# 0       notpresent  notpresent            121.000000        36.0  ...
# 1       notpresent  notpresent            148.036517        18.0  ...
# 2       notpresent  notpresent            423.000000        53.0  ...
# 3          present  notpresent            117.000000        56.0  ...
# 4       notpresent  notpresent            106.000000        26.0  ...
# 5       notpresent  notpresent             74.000000        25.0  ...
# 6       notpresent  notpresent            100.000000        54.0  ...
# 7       notpresent  notpresent            410.000000        31.0  ...
# 8          present  notpresent            138.000000        60.0  ...
# 9          present  notpresent             70.000000       107.0  ...
# 10         present  notpresent            490.000000        55.0  ...
# 11         present  notpresent            380.000000        60.0  ...
# 12         present  notpresent            208.000000        72.0  ...
# 13      notpresent  notpresent             98.000000        86.0  ...
# 14         present     present            157.000000        90.0  ...
# 15      notpresent  notpresent             76.000000       162.0  ...
# 16      notpresent  notpresent             99.000000        46.0  ...
# 17      notpresent  notpresent            114.000000        87.0  ...
# 18      notpresent  notpresent            263.000000        27.0  ...
# 19         present  notpresent            100.000000        31.0  ...
#
#     Hemoglobin  Packed_Cell_Volume  WhiteBC_Count  Hypertension  \
# 0         15.4           44.000000    7800.000000           yes
# 1         11.3           38.000000    6000.000000            no
# 2          9.6           31.000000    7500.000000            no
# 3         11.2           32.000000    6700.000000           yes
# 4         11.6           35.000000    7300.000000            no
# 5         12.2           39.000000    7800.000000           yes
# 6         12.4           36.000000    8406.122449            no
# 7         12.4           44.000000    6900.000000            no
# 8         10.8           33.000000    9600.000000           yes
# 9          9.5           29.000000   12100.000000           yes
# 10         9.4           28.000000    8406.122449           yes
# 11        10.8           32.000000    4500.000000           yes
# 12         9.7           28.000000   12200.000000           yes
# 13         9.8           38.884498    8406.122449           yes
# 14         5.6           16.000000   11000.000000           yes
# 15         7.6           24.000000    3800.000000           yes
# 16        12.6           38.884498    8406.122449            no
# 17        12.1           38.884498    8406.122449           yes
# 18        12.7           37.000000   11400.000000           yes
# 19        10.3           30.000000    5300.000000           yes
#
#     Diabetes_Mellitus  Coronary_Artery_Disease Appetite Pedal_Edema Anemia  \
# 0                 yes                       no     good          no     no
# 1                  no                       no     good          no     no
# 2                 yes                       no     poor          no    yes
# 3                  no                       no     poor         yes    yes
# 4                  no                       no     good          no     no
# 5                 yes                       no     good         yes     no
# 6                  no                       no     good          no     no
# 7                 yes                       no     good         yes     no
# 8                 yes                       no     good          no    yes
# 9                 yes                       no     poor          no    yes
# 10                yes                       no     good          no    yes
# 11                yes                       no     poor         yes     no
# 12                yes                      yes     poor         yes     no
# 13                yes                      yes     poor         yes     no
# 14                yes                      yes     poor         yes     no
# 15                 no                       no     good          no    yes
# 16                 no                       no     good          no     no
# 17                 no                       no     poor          no     no
# 18                yes                      yes     good          no     no
# 19                 no                      yes     good          no     no
#
#    Class
# 0    ckd
# 1    ckd
# 2    ckd
# 3    ckd
# 4    ckd
# 5    ckd
# 6    ckd
# 7    ckd
# 8    ckd
# 9    ckd
# 10   ckd
# 11   ckd
# 12   ckd
# 13   ckd
# 14   ckd
# 15   ckd
# 16   ckd
# 17   ckd
# 18   ckd
# 19   ckd
#
# [20 rows x 23 columns]

# %%
# replace cat
print('Null values count in Categorical Features \n')

for i in obj_features:
    print(i, ': ', data[i].isna().mean())
# Out:
# Null values count in Categorical Features
#
# Pus_Cell :  0.1625
# Pus_Cell_Clumps :  0.01
# Bacteria :  0.01
# Hypertension :  0.005
# Diabetes_Mellitus :  0.005
# Coronary_Artery_Disease :  0.005
# Appetite :  0.0025
# Pedal_Edema :  0.0025
# Anemia :  0.0025
# Class :  0.0

# %%
data = data.apply(lambda x: x.fillna(x.value_counts().index[0]))
data
# Out:
#       Age  Blood_Pressure  Specific_Gravity  Albumin  Sugar  Pus_Cell  \
# 0    48.0            80.0             1.020      1.0    0.0    normal
# 1     7.0            50.0             1.020      4.0    0.0    normal
# 2    62.0            80.0             1.010      2.0    3.0    normal
# 3    48.0            70.0             1.005      4.0    0.0  abnormal
# 4    51.0            80.0             1.010      2.0    0.0    normal
# ..    ...             ...               ...      ...    ...       ...
# 395  55.0            80.0             1.020      0.0    0.0    normal
# 396  42.0            70.0             1.025      0.0    0.0    normal
# 397  12.0            80.0             1.020      0.0    0.0    normal
# 398  17.0            60.0             1.025      0.0    0.0    normal
# 399  58.0            80.0             1.025      0.0    0.0    normal
#
#     Pus_Cell_Clumps    Bacteria  Blood_Glucose_Random  Blood_Urea  ...  \
# 0        notpresent  notpresent            121.000000        36.0  ...
# 1        notpresent  notpresent            148.036517        18.0  ...
# 2        notpresent  notpresent            423.000000        53.0  ...
# 3           present  notpresent            117.000000        56.0  ...
# 4        notpresent  notpresent            106.000000        26.0  ...
# ..              ...         ...                   ...         ...  ...
# 395      notpresent  notpresent            140.000000        49.0  ...
# 396      notpresent  notpresent             75.000000        31.0  ...
# 397      notpresent  notpresent            100.000000        26.0  ...
# 398      notpresent  notpresent            114.000000        50.0  ...
# 399      notpresent  notpresent            131.000000        18.0  ...
#
#      Hemoglobin  Packed_Cell_Volume  WhiteBC_Count  Hypertension  \
# 0          15.4                44.0         7800.0           yes
# 1          11.3                38.0         6000.0            no
# 2           9.6                31.0         7500.0            no
# 3          11.2                32.0         6700.0           yes
# 4          11.6                35.0         7300.0            no
# ..          ...                 ...            ...           ...
# 395        15.7                47.0         6700.0            no
# 396        16.5                54.0         7800.0            no
# 397        15.8                49.0         6600.0            no
# 398        14.2                51.0         7200.0            no
# 399        15.8                53.0         6800.0            no
#
#      Diabetes_Mellitus  Coronary_Artery_Disease Appetite Pedal_Edema Anemia  \
# 0                  yes                       no     good          no     no
# 1                   no                       no     good          no     no
# 2                  yes                       no     poor          no    yes
# 3                   no                       no     poor         yes    yes
# 4                   no                       no     good          no     no
# ..                 ...                      ...      ...         ...    ...
# 395                 no                       no     good          no     no
# 396                 no                       no     good          no     no
# 397                 no                       no     good          no     no
# 398                 no                       no     good          no     no
# 399                 no                       no     good          no     no
#
#       Class
# 0       ckd
# 1       ckd
# 2       ckd
# 3       ckd
# 4       ckd
# ..      ...
# 395  notckd
# 396  notckd
# 397  notckd
# 398  notckd
# 399  notckd
#
# [400 rows x 23 columns]

# %%
obj_features = np.array([])
numeric_features = np.array([])

for feature in data.columns:
    if data[feature].dtypes == object:
        obj_features = np.append(obj_features, feature)
    else:
        numeric_features = np.append(numeric_features, feature)

# %%
for i in obj_features:
    print(i, ': ', data[i].isna().sum())
# Out:
# Pus_Cell :  0
# Pus_Cell_Clumps :  0
# Bacteria :  0
# Hypertension :  0
# Diabetes_Mellitus :  0
# Coronary_Artery_Disease :  0
# Appetite :  0
# Pedal_Edema :  0
# Anemia :  0
# Class :  0

# %%
from sklearn import preprocessing   

label = preprocessing.LabelEncoder() 

for i in obj_features:
    data[i]= label.fit_transform(data[i])

# %% [markdown]
# Visualization

# %%
import seaborn as sns

corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))

g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="YlGnBu")

# %%
sns.countplot(x = 'Class',data = data)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
data.hist(figsize = (30,30))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Blood_Pressure'}>,
#         <AxesSubplot:title={'center':'Specific_Gravity'}>,
#         <AxesSubplot:title={'center':'Albumin'}>,
#         <AxesSubplot:title={'center':'Sugar'}>],
#        [<AxesSubplot:title={'center':'Pus_Cell'}>,
#         <AxesSubplot:title={'center':'Pus_Cell_Clumps'}>,
#         <AxesSubplot:title={'center':'Bacteria'}>,
#         <AxesSubplot:title={'center':'Blood_Glucose_Random'}>,
#         <AxesSubplot:title={'center':'Blood_Urea'}>],
#        [<AxesSubplot:title={'center':'Serum_Creatinine'}>,
#         <AxesSubplot:title={'center':'Sodium'}>,
#         <AxesSubplot:title={'center':'Potassium'}>,
#         <AxesSubplot:title={'center':'Hemoglobin'}>,
#         <AxesSubplot:title={'center':'Packed_Cell_Volume'}>],
#        [<AxesSubplot:title={'center':'WhiteBC_Count'}>,
#         <AxesSubplot:title={'center':'Hypertension'}>,
#         <AxesSubplot:title={'center':'Diabetes_Mellitus'}>,
#         <AxesSubplot:title={'center':'Coronary_Artery_Disease'}>,
#         <AxesSubplot:title={'center':'Appetite'}>],
#        [<AxesSubplot:title={'center':'Pedal_Edema'}>,
#         <AxesSubplot:title={'center':'Anemia'}>,
#         <AxesSubplot:title={'center':'Class'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
feature = data.drop('Class', axis=1)
label= data['Class']

# %%
label
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    2
# 396    2
# 397    2
# 398    2
# 399    2
# Name: Class, Length: 400, dtype: int32

# %%
from sklearn.model_selection import train_test_split

feature_train, feature_test, label_train, label_test = train_test_split(feature, label, test_size=0.2) 

print(feature_train.shape)
print(label_train.shape)
print(feature_test.shape)
print(label_test.shape)
# Out:
# (320, 22)
# (320,)
# (80, 22)
# (80,)

# %%
# importing the MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# creating a scaler
mm = MinMaxScaler()

# feeding the independent variable into the scaler
feature_train = mm.fit_transform(feature_train)
feature_test = mm.transform(feature_test)

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
model=RandomForestClassifier(n_estimators=100,random_state=24)


# feeding the training data to the model
model.fit(feature_train, label_train)

# predicting the test set results
# y_pred = model.predict(x_test)

# calculating the classification accuracies
print("Training Accuracy :", model.score(feature_train, label_train))
print("Testing Accuracy :", round(model.score(feature_test, label_test)*100.0,2))
# Out:
# Training Accuracy : 1.0
# Testing Accuracy : 100.0

# %%
from sklearn.linear_model import  LogisticRegression

# creating a model
model = LogisticRegression()


# feeding the training data to the model
model.fit(feature_train, label_train)

# predicting the test set results
# y_pred = model.predict(x_test)

# calculating the classification accuracies
print("Training Accuracy :", model.score(feature_train, label_train))
print("Testing Accuracy :", round(model.score(feature_test, label_test)*100.0,2))
# Out:
# Training Accuracy : 0.984375
# Testing Accuracy : 98.75

# %%
from sklearn.svm import SVC

# creating a model
model = SVC()


# feeding the training data to the model
model.fit(feature_train, label_train)

# predicting the test set results
# y_pred = model.predict(x_test)

# calculating the classification accuracies
print("Training Accuracy :", model.score(feature_train, label_train))
print("Testing Accuracy :", round(model.score(feature_test, label_test)*100.0,2))
# Out:
# Training Accuracy : 0.9875
# Testing Accuracy : 100.0
